# %%
import pandas  as pd
df_laptops = pd.read_csv("laptop_price.csv",encoding='unicode_escape')
df_laptops.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %% [markdown]
# ### drop_duplicates()

# %%
# drop duplicates in 1 columns
df_laptops.drop_duplicates("Company")[["Company","Price_euros"]]
# Out:
#        Company  Price_euros
# 0        Apple      1339.69
# 2           HP       575.00
# 5         Acer       400.00
# 8         Asus      1495.00
# 13        Dell       498.90
# 18      Lenovo       499.00
# 30       Chuwi       244.99
# 58         MSI      2449.00
# 70   Microsoft      1089.00
# 143    Toshiba       602.00
# 170     Huawei      1349.00
# 184     Xiaomi      1199.00
# 191       Vero       260.00
# 196      Razer      6099.00
# 429   Mediacom       299.00
# 430    Samsung       269.00
# 437     Google      2199.00
# 567    Fujitsu       739.00
# 678         LG      2299.00

# %%
# drop duplicates in 2 or more columns
df_laptops.drop_duplicates(["Company"])[["Company","Price_euros"]]
# Out:
#        Company  Price_euros
# 0        Apple      1339.69
# 2           HP       575.00
# 5         Acer       400.00
# 8         Asus      1495.00
# 13        Dell       498.90
# 18      Lenovo       499.00
# 30       Chuwi       244.99
# 58         MSI      2449.00
# 70   Microsoft      1089.00
# 143    Toshiba       602.00
# 170     Huawei      1349.00
# 184     Xiaomi      1199.00
# 191       Vero       260.00
# 196      Razer      6099.00
# 429   Mediacom       299.00
# 430    Samsung       269.00
# 437     Google      2199.00
# 567    Fujitsu       739.00
# 678         LG      2299.00

# %%
# chepest keep = "First"
df_laptops= df_laptops.sort_values(["Company","Price_euros"])
df_laptops.drop_duplicates("Company",keep="first")[["Company","Price_euros"]]
# Out:
#         Company  Price_euros
# 1215       Acer       174.00
# 1         Apple       898.94
# 20         Asus       191.90
# 30        Chuwi       244.99
# 340        Dell       274.90
# 983     Fujitsu       649.00
# 472      Google      1275.00
# 1268         HP       209.00
# 170      Huawei      1349.00
# 909          LG      1899.00
# 1272     Lenovo       229.00
# 1169        MSI       839.00
# 626    Mediacom       239.00
# 457   Microsoft       989.00
# 1117      Razer      1029.00
# 430     Samsung       269.00
# 159     Toshiba       447.00
# 1120       Vero       196.00
# 877      Xiaomi       935.00

# %%
# Most Expensive keep = "last"
df_laptops.drop_duplicates(["Company"],keep="last")[["Company","Price_euros"]]
# Out:
#         Company  Price_euros
# 1189       Acer      2599.00
# 17        Apple      2858.00
# 1066       Asus      3975.00
# 421       Chuwi       449.00
# 723        Dell      3659.40
# 623     Fujitsu       799.00
# 437      Google      2199.00
# 749          HP      4389.00
# 214      Huawei      1499.00
# 678          LG      2299.00
# 610      Lenovo      4899.00
# 177         MSI      2799.00
# 580    Mediacom       389.00
# 449   Microsoft      2589.00
# 196       Razer      6099.00
# 874     Samsung      1849.00
# 491     Toshiba      2799.00
# 191        Vero       260.00
# 514      Xiaomi      1399.95

# %% [markdown]
# ### Exercise 1
# Task: Find the biggest and smallest screen size in laptops of each company using the sort_values() and duplicated() methods (keep "first", "last" and False)

# %%
df_laptops=df_laptops.sort_values("Inches")
df_laptops
# Out:
#       laptop_ID Company            Product            TypeName  Inches  \
# 1126       1141  Lenovo          Yoga Book  2 in 1 Convertible    10.1
# 50           51  Lenovo          Yoga Book  2 in 1 Convertible    10.1
# 1114       1129  Lenovo          Yoga Book  2 in 1 Convertible    10.1
# 1082       1097  Lenovo          Yoga Book  2 in 1 Convertible    10.1
# 944         958  Lenovo     Yoga 700-11ISK  2 in 1 Convertible    11.3
# ...         ...     ...                ...                 ...     ...
# 1103       1118      HP           ZBook 17         Workstation    17.3
# 818         827    Dell       Alienware 17              Gaming    17.3
# 552         559    Dell       Alienware 17              Gaming    17.3
# 238         243    Asus  ROG G703VI-E5062T              Gaming    17.3
# 177         181     MSI    GT80S 6QF-074US              Gaming    18.4
#
#                                ScreenResolution                          Cpu  \
# 1126            IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz
# 50              IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz
# 1114            IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz
# 1082            IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz
# 944   IPS Panel Full HD / Touchscreen 1920x1080  Intel Core M m7-6Y75 1.2GHz
# ...                                         ...                          ...
# 1103                IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz
# 818                 IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 552                 IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 238                           Full HD 1920x1080  Intel Core i7 7820HK 2.9GHz
# 177                           Full HD 1920x1080  Intel Core i7 6920HQ 2.9GHz
#
#        Ram                Memory                      Gpu       OpSys  Weight  \
# 1126   4GB    64GB Flash Storage    Intel HD Graphics 400  Windows 10  0.69kg
# 50     4GB    64GB Flash Storage    Intel HD Graphics 400     Android  0.69kg
# 1114   4GB    64GB Flash Storage    Intel HD Graphics 400     Android  0.69kg
# 1082   4GB    64GB Flash Storage    Intel HD Graphics 400  Windows 10  0.69kg
# 944    8GB             256GB SSD    Intel HD Graphics 515  Windows 10   1.1kg
# ...    ...                   ...                      ...         ...     ...
# 1103   8GB               1TB HDD       AMD FirePro W6150M   Windows 7   3.0kg
# 818   16GB  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10  4.36kg
# 552   16GB  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10  4.42kg
# 238   32GB  512GB SSD +  1TB HDD  Nvidia GeForce GTX 1080  Windows 10   4.7kg
# 177   32GB  512GB SSD +  1TB HDD       Nvidia GTX 980 SLI  Windows 10   4.4kg
#
#       Price_euros
# 1126       479.00
# 50         319.00
# 1114       549.00
# 1082       646.27
# 944       1299.00
# ...           ...
# 1103      2899.00
# 818       2505.02
# 552       2699.00
# 238       3890.00
# 177       2799.00
#
# [1303 rows x 13 columns]

# %%
# smallest screen
df_laptops.drop_duplicates(["Company"],keep="first")[["Company","Inches"]]
# Out:
#         Company  Inches
# 1126     Lenovo    10.1
# 677          HP    11.6
# 455        Dell    11.6
# 348        Asus    11.6
# 461        Acer    11.6
# 430     Samsung    11.6
# 1234      Apple    11.6
# 429    Mediacom    11.6
# 421       Chuwi    12.3
# 437      Google    12.3
# 1117      Razer    12.5
# 963     Toshiba    12.5
# 214      Huawei    13.0
# 1120       Vero    13.3
# 192      Xiaomi    13.3
# 449   Microsoft    13.5
# 1161        MSI    14.0
# 909          LG    14.0
# 567     Fujitsu    15.6

# %%
# biggest screen
df_laptops.drop_duplicates(["Company"],keep="last")[["Company","Inches"]]
# Out:
#         Company  Inches
# 472      Google    12.3
# 170      Huawei    13.0
# 457   Microsoft    13.5
# 580    Mediacom    14.0
# 791        Vero    14.0
# 3         Apple    15.4
# 184      Xiaomi    15.6
# 623     Fujitsu    15.6
# 593     Samsung    15.6
# 143     Toshiba    15.6
# 678          LG    15.6
# 483       Chuwi    15.6
# 321      Lenovo    17.3
# 830       Razer    17.3
# 168        Acer    17.3
# 1103         HP    17.3
# 552        Dell    17.3
# 238        Asus    17.3
# 177         MSI    18.4
