# %% [markdown]
# # Introduction to Pandas and NumPy

# %% [markdown]
# ## --> Pandas (stands for Python Data Analysis) is an open-source software library designed for data manipulation and analysis.

# %% [markdown]
# ### ->Built on top of NumPy, efficiently manages large datasets, offering tools for data cleaning, transformation and analysis.
# ### ->Seamlessly integrates with other Python libraries like NumPy, Matplotlib and scikit-learn.
# ### ->Revolves around two primary Data structures: Series (1D) and DataFrame (2D)
# ### ->Provides methods like .dropna() and .fillna() to handle missing values seamlessly

# %% [markdown]
# ## -->What is Pandas Used for?

# %% [markdown]
# ### ->Reading and writing data from various file formats like CSV, Excel and SQL databases.
# ### ->Cleaning and preparing data (handling missing values, filtering, removing duplicates).
# ### ->Merging, joining, and reshaping datasets.
# ### ->Performing statistical analysis and descriptive statistics.
# ### ->Visualizing data quickly.

# %% [markdown]
# ## 1 Creating a dataframe from an array

# %% [markdown]
# ### 1.1 Option 1

# %%
import numpy as np
import pandas as pd

# %%
# creating an array
data = np.array([[1,2],[2,5],[3,6]])

# %%
# Creating dataframe
pd.DataFrame(data)
# Out:
#    0  1
# 0  1  2
# 1  2  5
# 2  3  6

# %%
# Creating dataframe
df = pd.DataFrame(data,index=['row1','row2','row3'],
                 columns = ['col1','col2'])

# %%
# showing the dataFrame
df
# Out:
#       col1  col2
# row1     1     2
# row2     2     5
# row3     3     6

# %% [markdown]
# ### 1.2 option 2

# %%
data = [[1,2],[2,5],[3,6]]

# %%
# Creating dataframe
df = pd.DataFrame(data,index=['row1','row2','row3'],
                 columns = ['col1','col2'])

# %%
# showing the dataFrame
df
# Out:
#       col1  col2
# row1     1     2
# row2     2     5
# row3     3     6

# %% [markdown]
# ## 2 Creating a DataFrame from a dictionary

# %%
city = ['Ahmedabad', 'Patan', 'Mehsana', 'Gandhinagar']
population = [345635,356748,567345,678935]

# %%
# storing lists within a dictionary
dict_state = {'City': city , 'Population':population}

# %%
# Creating dataframe
df_population = pd.DataFrame(dict_state)

# %%
# showing the dataFrame
df_population
# Out:
#           City  Population
# 0    Ahmedabad      345635
# 1        Patan      356748
# 2      Mehsana      567345
# 3  Gandhinagar      678935

# %% [markdown]
# ## 3 Creating a DataFrame from a csv file

# %%
# reading the csv file
df_exam =pd.read_csv('StudentsPerformance.csv')

# %%
# show first 5 rows in a dataframe
df_exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# show  last  5 rows in dataframe
df_exam.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# show n rows in dataframe
df_exam.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df_exam.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
df_exam.shape
# Out:
# (1000, 8)

# %%
df_exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# display n rows

# %%
# pd.set_option('display.max_rows', 1000)
# df_exam

# %% [markdown]
# ## 4 Attributes

# %%
# getting access to shape attribute
df_exam.shape
# Out:
# (1000, 8)

# %%
# getting access of index attribute
df_exam.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# getting access of columns attribuite
df_exam.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_exam.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# ## 6 Methods

# %%
df_exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df_exam.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ## 7 Function

# %%
len(df_exam)
# Out:
# 1000

# %%
max(df_exam)
# Out:
# 'writing score'

# %%
max(df_exam.index)
# Out:
# 999

# %%
min(df_exam)
# Out:
# 'gender'

# %%
type(df_exam)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 8 Selecting One Column

# %% [markdown]
# ### 8.1 Syntax 1

# %%
df_exam['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df_exam['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %% [markdown]
# ### 8.2 Syntax 2

# %%
df_exam.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
#df_exam.math score # SyntaxError: invalid syntax
df_exam['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %% [markdown]
# ## 9 Selecting two or more columns

# %%
df_exam[['gender','math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
df_exam[['gender','math score','reading score', 'writing score']]
# Out:
#      gender  math score  reading score  writing score
# 0    female          72             72             74
# 1    female          69             90             88
# 2    female          90             95             93
# 3      male          47             57             44
# 4      male          76             78             75
# ..      ...         ...            ...            ...
# 995  female          88             99             95
# 996    male          62             55             55
# 997  female          59             71             65
# 998  female          68             78             77
# 999  female          77             86             86
#
# [1000 rows x 4 columns]

# %% [markdown]
# ## 10 Adding new Column

# %% [markdown]
# ### 10.1 Adding a new column with a scalar value

# %%
df_exam['language score'] = 70

# %%
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ### 10.2 Adding a new column with an array

# %%
# create random integer bnumber b/n 1-100
int_language_score =np.random.randint(1,100,size=1000)

# %%
min(int_language_score)
max(int_language_score)
# Out:
# np.int32(99)

# %%
df_exam['language score'] = int_language_score
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# create random float number b/n 1-100
np.random.uniform(1,100,size=100)
# Out:
# array([57.32977905,  8.69232581, 16.7959835 , 26.149979  , 24.03586178,
#        29.18474634, 66.58432036, 75.2913755 , 55.46546076, 91.27965334,
#        32.42482132, 44.90764034, 37.66764891,  2.23674383,  6.03921687,
#        10.23902588, 84.74449589, 37.62332645, 72.49555893, 70.82688843,
#        79.92149524, 14.87064848, 12.53238662, 29.19667386,  6.8159652 ,
#        80.76041118,  7.70635144, 22.35472954, 43.91076719, 85.33720087,
#        80.63582079, 42.38823654, 54.65309176, 95.0338659 , 34.50484948,
#        79.91872014, 45.34430017, 94.83987667, 15.98411312, 76.73332631,
#        16.03912769, 10.41182532, 72.57942791, 38.89526833, 49.36198081,
#        65.4674322 , 57.52422049, 91.71694764, 79.51709777, 75.05591968,
#        70.0475133 , 53.69894107, 93.91584505, 27.69054789, 18.5527731 ,
#        18.60030424, 93.12343837, 67.7465394 , 25.87070657, 68.13146457,
#        14.90498903, 69.20170781, 61.26898646, 87.45600214, 61.72057169,
# ...

# %% [markdown]
# ### 10.3 assign()

# %% [markdown]
# When to use assign?
#  * Add multiple columns in a single line of code
#  * when you need to overwrite the value of an eexiting columns
#
#
# it return a new object(a copy) with all the original columns in addition to the new ones

# %%
# create random number for our new score columns
score1 = np.random.randint(1,100,size=1000)
score2 = np.random.randint(1,100,size=1000)

# %%
# create a series using the random number 
series1=pd.Series(score1,index=np.arange(0,1000))
series2=pd.Series(score2,index=np.arange(0,1000))

# %%
series1
# Out:
# 0      47
# 1      34
# 2      99
# 3      59
# 4       6
#        ..
# 995    54
# 996    49
# 997    63
# 998    53
# 999    86
# Length: 1000, dtype: int32

# %%
series2
# Out:
# 0       9
# 1      18
# 2       1
# 3       1
# 4      52
#        ..
# 995    50
# 996    15
# 997     6
# 998     4
# 999    98
# Length: 1000, dtype: int32

# %%
df_exam.assign(score1=series1,score2=series2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df_exam=df_exam.assign(score1=series1,score2=series2)
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ### 10.4 insert()

# %%
df_exam.insert(1,'test' , series1)

# %%
df_exam
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    47        group B           bachelor's degree      standard
# 1    female    34        group C                some college      standard
# 2    female    99        group B             master's degree      standard
# 3      male    59        group A          associate's degree  free/reduced
# 4      male     6        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    54        group E             master's degree      standard
# 996    male    49        group C                 high school  free/reduced
# 997  female    63        group C                 high school  free/reduced
# 998  female    53        group D                some college      standard
# 999  female    86        group D                some college  free/reduced
#
# ...

# %% [markdown]
# ## 11 Operations on Dataframe

# %% [markdown]
# ### 1 Math Operation

# %% [markdown]
# ### 1.1 Operation in column

# %%
# select a column and calculate total sum
df_exam['math score'].sum()
# Out:
# np.int64(66089)

# %%
# count ,mean,std,max,min
print(df_exam['math score'].count())
print(df_exam['math score'].mean())
print(df_exam['math score'].std())
print(df_exam['math score'].max())
print(df_exam['math score'].min())
# Out:
# 1000
# 66.089
# 15.163080096009468
# 100
# 0

# %%
# easier calculation with .describe()
df_exam.describe()
# Out:
#               test  math score  reading score  writing score  language score  \
# count  1000.000000  1000.00000    1000.000000    1000.000000      1000.00000
# mean     48.705000    66.08900      69.169000      68.054000        49.52200
# std      28.340522    15.16308      14.600192      15.195657        29.09715
# min       1.000000     0.00000      17.000000      10.000000         1.00000
# 25%      24.000000    57.00000      59.000000      57.750000        23.00000
# 50%      49.000000    66.00000      70.000000      69.000000        49.00000
# 75%      73.000000    77.00000      79.000000      79.000000        74.00000
# max      99.000000   100.00000     100.000000     100.000000        99.00000
#
#             score1       score2
# count  1000.000000  1000.000000
# mean     48.705000    51.177000
# std      28.340522    29.026854
# min       1.000000     1.000000
# 25%      24.000000    26.000000
# 50%      49.000000    52.000000
# 75%      73.000000    77.000000
# ...

# %% [markdown]
# ###  1.2 Operation in rows

# %%
# calculating the sum in a row
df_exam['math score']+df_exam['reading score']+df_exam['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
# calculation the average and assigning the result to a new column
df_exam['average']=(df_exam['math score']+df_exam['reading score']+df_exam['writing score'])/3

# %%
df_exam
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    47        group B           bachelor's degree      standard
# 1    female    34        group C                some college      standard
# 2    female    99        group B             master's degree      standard
# 3      male    59        group A          associate's degree  free/reduced
# 4      male     6        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    54        group E             master's degree      standard
# 996    male    49        group C                 high school  free/reduced
# 997  female    63        group C                 high school  free/reduced
# 998  female    53        group D                some college      standard
# 999  female    86        group D                some college  free/reduced
#
# ...

# %%
df_exam.round(2)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    47        group B           bachelor's degree      standard
# 1    female    34        group C                some college      standard
# 2    female    99        group B             master's degree      standard
# 3      male    59        group A          associate's degree  free/reduced
# 4      male     6        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    54        group E             master's degree      standard
# 996    male    49        group C                 high school  free/reduced
# 997  female    63        group C                 high school  free/reduced
# 998  female    53        group D                some college      standard
# 999  female    86        group D                some college  free/reduced
#
# ...

# %% [markdown]
# ## 12 Value Counts

# %%
# counting gender element by category
df_exam['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
# return relative frequency
df_exam['gender'].value_counts(normalize=True)
# Out:
# gender
# female    0.518
# male      0.482
# Name: proportion, dtype: float64

# %%
df_exam['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
df_exam['parental level of education'].value_counts(normalize=True).round(2)
# Out:
# parental level of education
# some college          0.23
# associate's degree    0.22
# high school           0.20
# some high school      0.18
# bachelor's degree     0.12
# master's degree       0.06
# Name: proportion, dtype: float64

# %% [markdown]
# ## 13 Sort dataframe

# %%
df_exam.sort_values('math score')
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 59   female    97        group C            some high school  free/reduced
# 980  female     5        group B                 high school  free/reduced
# 17   female    84        group B            some high school  free/reduced
# 787  female    47        group B                some college      standard
# 145  female    51        group C                some college  free/reduced
# ..      ...   ...            ...                         ...           ...
# 625    male    51        group D                some college      standard
# 623    male    51        group A                some college      standard
# 451  female    69        group E                some college      standard
# 962  female    84        group E          associate's degree      standard
# 149    male    74        group E          associate's degree  free/reduced
#
# ...

# %%
df_exam.sort_values('math score', ascending=False)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 962  female    84        group E          associate's degree      standard
# 625    male    51        group D                some college      standard
# 458  female    67        group E           bachelor's degree      standard
# 623    male    51        group A                some college      standard
# 451  female    69        group E                some college      standard
# ..      ...   ...            ...                         ...           ...
# 145  female    51        group C                some college  free/reduced
# 787  female    47        group B                some college      standard
# 17   female    84        group B            some high school  free/reduced
# 980  female     5        group B                 high school  free/reduced
# 59   female    97        group C            some high school  free/reduced
#
# ...

# %%
df_exam.sort_values(['math score','reading score']) 
# its only make copy dont upgrade data frame
# for update use inplace=True
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 59   female    97        group C            some high school  free/reduced
# 980  female     5        group B                 high school  free/reduced
# 17   female    84        group B            some high school  free/reduced
# 787  female    47        group B                some college      standard
# 145  female    51        group C                some college  free/reduced
# ..      ...   ...            ...                         ...           ...
# 625    male    51        group D                some college      standard
# 149    male    74        group E          associate's degree  free/reduced
# 458  female    67        group E           bachelor's degree      standard
# 916    male    89        group E           bachelor's degree      standard
# 962  female    84        group E          associate's degree      standard
#
# ...

# %%
df_exam.sort_values('race/ethnicity')
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 778  female    22        group A                some college      standard
# 546  female    57        group A            some high school      standard
# 820  female    85        group A            some high school      standard
# 741  female    45        group A          associate's degree  free/reduced
# 305    male    53        group A                some college      standard
# ..      ...   ...            ...                         ...           ...
# 297    male    46        group E          associate's degree      standard
# 293  female    21        group E           bachelor's degree      standard
# 289    male    87        group E            some high school      standard
# 206    male    60        group E           bachelor's degree      standard
# 499    male    59        group E                some college      standard
#
# ...

# %% [markdown]
# ## 14 Create Index

# %%
import random

# %%
new_index = np.arange(0,1000)

# %%
random.shuffle(new_index)

# %%
df_exam['new_index']=new_index

# %%
df_exam
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    47        group B           bachelor's degree      standard
# 1    female    34        group C                some college      standard
# 2    female    99        group B             master's degree      standard
# 3      male    59        group A          associate's degree  free/reduced
# 4      male     6        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    54        group E             master's degree      standard
# 996    male    49        group C                 high school  free/reduced
# 997  female    63        group C                 high school  free/reduced
# 998  female    53        group D                some college      standard
# 999  female    86        group D                some college  free/reduced
#
# ...

# %% [markdown]
# ## 15 Set Index

# %%
df_exam.set_index('new_index', inplace=True)

# %%
df_exam
# Out:
#            gender  test race/ethnicity parental level of education  \
# new_index
# 379        female    47        group B           bachelor's degree
# 562        female    34        group C                some college
# 604        female    99        group B             master's degree
# 352          male    59        group A          associate's degree
# 484          male     6        group C                some college
# ...           ...   ...            ...                         ...
# 511        female    54        group E             master's degree
# 144          male    49        group C                 high school
# 720        female    63        group C                 high school
# 769        female    53        group D                some college
# 981        female    86        group D                some college
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# ...

# %% [markdown]
# ## 16 sort index

# %%
df_exam.sort_index()
# Out:
#            gender  test race/ethnicity parental level of education  \
# new_index
# 0          female    83        group A            some high school
# 1          female    37        group C                 high school
# 2            male    77        group E            some high school
# 3          female    94        group C                some college
# 4            male     4        group B                some college
# ...           ...   ...            ...                         ...
# 995          male    82        group C          associate's degree
# 996          male    93        group A           bachelor's degree
# 997          male    59        group E                some college
# 998          male    41        group B                 high school
# 999          male    91        group D                some college
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# ...

# %%
df_exam =pd.read_csv('StudentsPerformance.csv')

# %%
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ## 1 Rename Column

# %%
df_exam=df_exam.rename(columns={'gender':'Gender'})

# %%
df_exam
# Out:
#      Gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_exam.rename(columns={'math score':'MS',
                               'reading score':'RS',
                               'writing score': 'Ws'}, inplace=True)

# %%
df_exam.head(3)
# Out:
#    Gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  MS  RS  Ws
# 0                    none  72  72  74
# 1               completed  69  90  88
# 2                    none  90  95  93

# %%
df_exam.rename(index={0:'A',1:'B',2:'C'},inplace=True)

# %%
df_exam.head(3)
# Out:
#    Gender race/ethnicity parental level of education     lunch  \
# A  female        group B           bachelor's degree  standard
# B  female        group C                some college  standard
# C  female        group B             master's degree  standard
#
#   test preparation course  MS  RS  Ws
# A                    none  72  72  74
# B               completed  69  90  88
# C                    none  90  95  93
